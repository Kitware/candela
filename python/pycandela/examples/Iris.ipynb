# %%
import sys
sys.path.append('..')

import pycandela
pycandela.init()

# %%
import json
data = json.load(open('../../../app/resonant-laboratory/scripts/library/Data/iris/iris.json'))

# %%
from pandas import DataFrame
df = DataFrame.from_records(data)

# %%
pycandela.component('ScatterPlotMatrix', {
    'data': df,
    'color': 'species',
    'fields': ['sepalLength', 'sepalWidth', 'petalLength', 'petalWidth']
})

# %%
pycandela.component('ScatterPlot', {
    'data': df,
    'color': 'species',
    'x': 'sepalLength',
    'y': 'sepalWidth'
})
